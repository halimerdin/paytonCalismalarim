# %%
bin(4)
# Out:
# '0b100'

# %%
bin(19)
# Out:
# '0b10011'

# %%
bin(521)
# Out:
# '0b1000001001'

# %%
hex(20)
# Out:
# '0x14'

# %%
hex(16)
# Out:
# '0x10'

# %%
hex(512)
# Out:
# '0x200'

# %%
#bir sayının mutlak değeri
abs(-5)
# Out:
# 5

# %% [markdown]
# ### round fonksiyonu

# %%
round(4.8)
# Out:
# 5

# %%
round(4.5)
# Out:
# 4

# %%
round(5.51)
# Out:
# 6

# %%
round(3.2229,3)
# Out:
# 3.223

# %%
round(3.2224,3)
# Out:
# 3.222

# %% [markdown]
# ### max ve min

# %%
max(3,4,5,6,10,-2)
# Out:
# 10

# %%
min(3,4,5,6,10,-2)
# Out:
# -2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sum(3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24872/3109718759.py in <module>
# ----> 1 sum(3,4)
#
# TypeError: 'int' object is not iterable

# %%
sum([1,2,3,4,5])
# Out:
# 15

# %%
sum((1,2,3,4,5))
# Out:
# 15

# %%
sum((1,2,3.4,4,5))
# Out:
# 15.4

# %%
sum((1,2,"3.4",4,5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24872/2382526256.py in <module>
# ----> 1 sum((1,2,"3.4",4,5))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pow(3,4)
# Out:
# 81

# %%
pow(9,0.5)
# Out:
# 3.0

# %%
pow(9,-2)
# Out:
# 0.012345679012345678

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# daha fazlası için
#
# ### https://www.tutorialspoint.com/python3/python_strings.htm

# %%
"python".upper()
# Out:
# 'PYTHON'

# %%
"PYTHON".lower()
# Out:
# 'python'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"herkes ana baba bacı kardeş".replace("a","0")
# Out:
# 'herkes 0n0 b0b0 b0cı k0rdeş'

# %%
"herkes ana baba bacı kardeş".replace(" ","-")
# Out:
# 'herkes-ana-baba-bacı-kardeş'

# %%
"halim halin falin".replace("li","on")
# Out:
# 'haonm haonn faonn'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"Python".startswith("p")
# Out:
# False

# %%
"Python".startswith("P")
# Out:
# True

# %%
"Python".endswith("on")
# Out:
# True

# %%
"Python".endswith("an")
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
liste="python programlama dili".split(" ")

# %%
print(liste)
# Out:
# ['python', 'programlama', 'dili']

# %%
liste2="python-c++-php".split("-")
print(liste2)
# Out:
# ['python', 'c++', 'php']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"                   python             ".strip()
# Out:
# 'python'

# %%
"                   python             ".lstrip()
# Out:
# 'python             '

# %%
"                   python             ".rstrip()
# Out:
# '                   python'

# %%
"<<<<<<<<<<<<<<<<<<python<<<<<<<<<<<<<<<".strip("<")
# Out:
# 'python'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
liste=["21","02","2011"]

"/".join(liste)
# Out:
# '21/02/2011'

# %%
liste2=["t","b","m","m"]
".".join(liste2)
# Out:
# 't.b.m.m'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"ada kapısı yandan çarklı".count("a")
# Out:
# 6

# %%
"ada kapısı yandan çarklı".count(" ")
# Out:
# 3

# %%
"ada kapısı yandan çarklı".count("")
# Out:
# 25

# %%
"ada kapısı yandan çarklı".count("a",2)
# Out:
# 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
"araba".find("a")
# Out:
# 0

# %%
"araba".rfind("a")
# Out:
# 4

# %%
"araba".rfind("s")
# Out:
# -1

# %%
"araba".find("s")
# Out:
# -1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x={1,2,3}

# %%
type(x)
# Out:
# set

# %%
x=set()

# %%
type(x)
# Out:
# set

# %%
liste=[1,2,3,4,5,5,4,3,2,1]

# %%
x=set(liste)

# %%
print(x)
# Out:
# {1, 2, 3, 4, 5}

# %%
x=set("python programlama dili")

# %%
print(x)
# Out:
# {'n', 'o', 't', 'g', 'l', 'm', 'p', 'h', 'r', 'a', 'i', 'y', ' ', 'd'}

# %%
x={"python","php","python"}

# %%
x
# Out:
# {'php', 'python'}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x={"muz","armut","elma","kiraz"}
for i in x:
    print(i)
# Out:
# kiraz
# elma
# muz
# armut

# %%
x={"python","php","java"}

# %%
x[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24872/3629782281.py in <module>
# ----> 1 x[0]
#
# TypeError: 'set' object is not subscriptable

# %%
x["python"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24872/1941209655.py in <module>
# ----> 1 x["python"]
#
# TypeError: 'set' object is not subscriptable

# %%
liste=list(x)
liste
# Out:
# ['php', 'java', 'python']

# %%
for i in liste:
    print(i)
# Out:
# php
# java
# python

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x={1,2,3,4,5}
x.add(6)
x
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
x.add(4)

# %%
x
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
kume1={1,2,3,4,5,65,32,31}
kume2={1,2,34,58,87}

# %%
kume1.difference(kume2)
# Out:
# {3, 4, 5, 31, 32, 65}

# %%
kume2.difference(kume1)
# Out:
# {34, 58, 87}

# %%
kume1
# Out:
# {1, 2, 3, 4, 5, 31, 32, 65}

# %%
kume2
# Out:
# {1, 2, 34, 58, 87}

# %%
kume1.difference_update(kume2)

# %%
kume1
# Out:
# {3, 4, 5, 31, 32, 65}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x={1, 2, 3, 4, 5, 6}
x.discard(6)

# %%
x
# Out:
# {1, 2, 3, 4, 5}

# %%
x.discard(120)

# %%
x
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
kume1={1,2,3,4,5,65,32,31}
kume2={1,2,34,58,87}

# %%
kume1.intersection(kume2)
# Out:
# {1, 2}

# %%
kume1.intersection_update(kume2)

# %%
kume1
# Out:
# {1, 2}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
kume1={1,2,3,4,5,65,32,31}
kume2={1,2,34,58,87}
kume3={12,25,50}

# %%
kume1.isdisjoint(kume2)
# Out:
# False

# %%
kume1.isdisjoint(kume3)
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
kume2={1,2,3,4,5,6}
kume1={1,2,3,4}
kume3={12,25,50}

# %%
kume1.issubset(kume2)
# Out:
# True

# %%
kume1.issubset(kume3)
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
kume1={1,2,3,4,5,65,32,31}
kume2={1,2,34,58,87}

# %%
kume1.union(kume2)
# Out:
# {1, 2, 3, 4, 5, 31, 32, 34, 58, 65, 87}

# %%
kume1.update(kume2)

# %%
kume1
# Out:
# {1, 2, 3, 4, 5, 31, 32, 34, 58, 65, 87}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
liste=[1,2,3,4,5]
liste.append(6)
liste
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
liste.append("6")
liste
# Out:
# [1, 2, 3, 4, 5, 6, '6']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
liste1=[1, 2, 3, 4, 5, 6,7]
liste2=[10,20,30]

# %%
liste1.extend(liste2)

# %%
liste1
# Out:
# [1, 2, 3, 4, 5, 6, 7, 10, 20, 30]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
liste=[1, 2, 3, 4, 5, 6, 7, 10, 20, 30]

# %%
liste.insert(2,"python")

# %%
liste
# Out:
# [1, 2, 'python', 3, 4, 5, 6, 7, 10, 20, 30]

# %%
liste.insert(0,"java")
liste
# Out:
# ['java', 1, 2, 'python', 3, 4, 5, 6, 7, 10, 20, 30]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
liste=[1, 2, 3, 4, 5, 6, 7]

# %%
liste.pop()
# Out:
# 7

# %%
liste
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
liste.pop(2)
# Out:
# 3

# %%
liste
# Out:
# [1, 2, 4, 5, 6]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
liste=["python","java","c","php"]

# %%
liste.remove("python")
liste
# Out:
# ['java', 'c', 'php']

# %%
liste.remove("a")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24872/3600001607.py in <module>
# ----> 1 liste.remove("a")
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
liste=[1, 2, 3, 4,3,3,5, 5, 6, 7,8,9]

# %%
liste.index(3)
# Out:
# 2

# %%
liste.index(3,3)
# Out:
# 4

# %%
liste.index("3,3")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24872/1750140714.py in <module>
# ----> 1 liste.index("3,3")
#
# ValueError: '3,3' is not in list

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
liste=[1, 2, 3, 4,3,3,5, 5, 6, 7,8,9]

# %%
liste.count(3)
# Out:
# 3

# %%
liste.count(10)
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
liste=[12,-2,3,1,34,100]

# %%
liste.sort()
liste
# Out:
# [-2, 1, 3, 12, 34, 100]

# %%
liste=["python","java","c","php"]

# %%
liste.sort()
liste
# Out:
# ['c', 'java', 'php', 'python']

# %% [markdown]
# tersten sıralama

# %%
liste=[12,-2,3,1,34,100]
liste.sort(reverse=True)
liste
# Out:
# [100, 34, 12, 3, 1, -2]

# %%
liste=["python","java","c","php"]
liste.sort(reverse=True)
liste
